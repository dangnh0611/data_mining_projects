# %%
import pandas as pd
import numpy as np
import json
import sys
from apyori import apriori
import networkx as nx 
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt

# %% [markdown]
# # Data preprocessing

# %%
df=pd.read_csv('data/data.csv')
df.sample(5)
# Out:
#            DATENEW                               RECEIPT             NAME  \
# 265980  2017-07-11  e1888fb2-6d39-4cbe-a105-4c7e951f5a32  Lettuce Iceberg
# 597159  2019-05-21  3896ba43-3246-4386-9765-45330307a5ad           Ginger
# 308088  2017-10-04  e20a72ed-db1c-46a5-9966-8fd4d4f8bcb4    Gold Honeydew
# 131067  2016-11-20  735d7f5a-11b9-4639-b39e-f6b096a5f071     Capsicum red
# 349899  2017-12-22  633deefe-8bc5-4285-9a9d-9eb01e5c1f84             Leek
#
#         UNITS
# 265980  1.000
# 597159  0.034
# 308088  2.000
# 131067  0.192
# 349899  1.000

# %%
print(df.shape)
df.drop_duplicates(inplace=True)
print(df.shape)
df.describe(include='all')
# Out:
# (659221, 4)
# (655837, 4)
#            DATENEW                               RECEIPT              NAME  \
# count       655837                                655837            655837
# unique        1280                                181970              1265
# top     2016-12-24  e6b225f3-96d3-4940-9065-90bd5b86f636  Banana Cavendish
# freq           987                                    36             43688
# mean           NaN                                   NaN               NaN
# std            NaN                                   NaN               NaN
# min            NaN                                   NaN               NaN
# 25%            NaN                                   NaN               NaN
# 50%            NaN                                   NaN               NaN
# 75%            NaN                                   NaN               NaN
# max            NaN                                   NaN               NaN
#
#                 UNITS
# count   655837.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.903796
# std          0.756547
# min         -1.000000
# 25%          0.452000
# 50%          1.000000
# 75%          1.000000
# max         48.000000

# %%
groups=df.groupby('RECEIPT')
baskets=[]
for name, group in groups:
    baskets.append(group['NAME'].tolist())

# %%
print(len(baskets))
print(baskets[0:5])
# Out:
# 181970
# [['Avocado Hass Medium', 'Lemon Puff 2 for 2.50', 'Zucchini green', 'Soya Meet Prawn 90g', 'Derana Jack Mackerel 425g', 'Papadam 200g derana'], ['Lettuce Iceberg', 'Broccoli', 'Cucumber Lebanese'], ['Banana Cavendish', 'Brushed Potatoes 5kg bag'], ['Avocado Hass Medium', 'Pear Packham', 'Lemon', 'Carrots ', 'Cucumber Lebanese', 'Apples Pink Lady', 'Field Tomatoes'], ['Watermelon seeded', 'Mandarin Imperial']]

# %% [markdown]
# # Association rules base on apriori algorithm

# %%
ass_rules = apriori(baskets, min_support=0.002, min_confidence=0.3, min_lift=1.5, min_length=2)
ass_results = list(ass_rules)
print(len(ass_results))
# Out:
# 143

# %%
ass_results=sorted(list(ass_results), key=lambda x: x[1], reverse=True)

# %%
ass_results[0][2][0]
# Out:
# OrderedStatistic(items_base=frozenset({'Mandarin Imperial'}), items_add=frozenset({'Banana Cavendish'}), confidence=0.4013472615444694, lift=1.6895264807469197)

# %%
one2one_rules=[]
supports=[]
confidences=[]
lifts=[]
for i,item in enumerate(ass_results):
    print(f"\n---------{i+1}----------")
    antecedent = list(item[2][0][0])
    consequent = list(item[2][0][1])
    print("Rule: " + str(antecedent) + " -> " + str(consequent))

    print("    - Support: " + str(item[1]))
    print("    - Confidence: " + str(item[2][0][2]))
    print("    - Lift: " + str(item[2][0][3]))
    
    if len(antecedent)==1 and len(consequent)==1:
        one2one_rules.append((antecedent[0], consequent[0]))
        supports.append(item[1])
        confidences.append(item[2][0][2])
        lifts.append(item[2][0][3])
# Out:
# ---------1----------
# Rule: ['Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.0225916359839534
#     - Confidence: 0.4013472615444694
#     - Lift: 1.6895264807469197
#
# ---------2----------
# Rule: ['Apples Pink Lady'] -> ['Banana Cavendish']
#     - Support: 0.01992086607682585
#     - Confidence: 0.44719960523069335
#     - Lift: 1.8825482259659303
#
# ---------3----------
# Rule: ['Pear Packham'] -> ['Banana Cavendish']
#     - Support: 0.018926196625817442
#     - Confidence: 0.46030473135525257
#     - Lift: 1.9377160562776807
#
# ---------4----------
# Rule: ['Apples Royal Gala'] -> ['Banana Cavendish']
#     - Support: 0.012513051601912403
#     - Confidence: 0.4247341913822048
#     - Lift: 1.7879769774867516
#
# ---------5----------
# Rule: ['Orange navel'] -> ['Banana Cavendish']
#     - Support: 0.012375666318623949
#     - Confidence: 0.3597444089456869
#     - Lift: 1.5143935525446282
#
# ---------6----------
# Rule: ['Nectarine White'] -> ['Banana Cavendish']
#     - Support: 0.011260097818321702
#     - Confidence: 0.36029541058554604
#     - Lift: 1.516713069707632
#
# ---------7----------
# Rule: ['Berries Strawberry (medium)'] -> ['Banana Cavendish']
#     - Support: 0.010314887069297137
#     - Confidence: 0.43671475104699864
#     - Lift: 1.8384107906637597
#
# ---------8----------
# Rule: ['Capsicum green'] -> ['Capsicum red']
#     - Support: 0.010062098148046381
#     - Confidence: 0.3332726610848198
#     - Lift: 5.313266702085566
#
# ---------9----------
# Rule: ['Apples Granny Smith'] -> ['Banana Cavendish']
#     - Support: 0.010012639446062538
#     - Confidence: 0.36007905138339924
#     - Lift: 1.5158022758978684
#
# ---------10----------
# Rule: ['Nectarine Yellow'] -> ['Banana Cavendish']
#     - Support: 0.008501401329889541
#     - Confidence: 0.3907552412225309
#     - Lift: 1.6449379148509946
#
# ---------11----------
# Rule: ['Kiwi fruit Green'] -> ['Banana Cavendish']
#     - Support: 0.0066329614771665655
#     - Confidence: 0.47632202052091555
#     - Lift: 2.0051430373190597
#
# ---------12----------
# Rule: ['Avocado Hass Medium'] -> ['Banana Cavendish']
#     - Support: 0.006545034895861955
#     - Confidence: 0.38111999999999996
#     - Lift: 1.6043770421264485
#
# ---------13----------
# Rule: ['Field Tomatoes', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.005654778260152773
#     - Confidence: 0.5285053929121726
#     - Lift: 2.2248161183572313
#
# ---------14----------
# Rule: ['Field Tomatoes', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.005347035225586635
#     - Confidence: 0.41439522998296424
#     - Lift: 1.7444536979202814
#
# ---------15----------
# Rule: ['navel oranges 3kg'] -> ['Banana Cavendish']
#     - Support: 0.005215145353629719
#     - Confidence: 0.3640199462984273
#     - Lift: 1.5323920148963568
#
# ---------16----------
# Rule: ['Capsicum red', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.00491289773039512
#     - Confidence: 0.43673668783585734
#     - Lift: 1.838503136592661
#
# ---------17----------
# Rule: ['Tomatoes Cherry'] -> ['Banana Cavendish']
#     - Support: 0.0045831730505028305
#     - Confidence: 0.3637156563453991
#     - Lift: 1.5311110645007118
#
# ---------18----------
# Rule: ['Pear Packham', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.004544705171182063
#     - Confidence: 0.609882005899705
#     - Lift: 2.5673821596124946
#
# ---------19----------
# Rule: ['Capsicum red', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0043853382425674565
#     - Confidence: 0.4854014598540146
#     - Lift: 2.043364185570015
#
# ---------20----------
# Rule: ['Apples Pink Lady', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.0043523657745782275
#     - Confidence: 0.5875370919881305
#     - Lift: 2.473318172185905
#
# ---------21----------
# Rule: ['Field Tomatoes', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.004330384129252075
#     - Confidence: 0.5228931652289317
#     - Lift: 2.2011906742709115
#
# ---------22----------
# Rule: ['Cauliflower half'] -> ['Broccoli']
#     - Support: 0.0043029070725943835
#     - Confidence: 0.34372256365232656
#     - Lift: 6.373262167089246
#
# ---------23----------
# Rule: ['Field Tomatoes', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.0041710172006374675
#     - Confidence: 0.46593001841620624
#     - Lift: 1.9613964756100828
#
# ---------24----------
# Rule: ['Berries Strawberry (large)'] -> ['Banana Cavendish']
#     - Support: 0.0041545309666428535
#     - Confidence: 0.38239757207890746
#     - Lift: 1.60975515745249
#
# ---------25----------
# Rule: ['Brussels sprouts'] -> ['Banana Cavendish']
#     - Support: 0.0041050722646590095
#     - Confidence: 0.37182677949228465
#     - Lift: 1.5652559526270857
#
# ---------26----------
# Rule: ['Potato sweet Gold', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.004099576853327472
#     - Confidence: 0.5275813295615276
#     - Lift: 2.220926146628523
#
# ---------27----------
# Rule: ['Capsicum red', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.0040885860306643955
#     - Confidence: 0.3970117395944504
#     - Lift: 1.6712755049853596
#
# ---------28----------
# Rule: ['Apples Red Delicious'] -> ['Banana Cavendish']
#     - Support: 0.004061108974006704
#     - Confidence: 0.42301087578706353
#     - Lift: 1.7807224435415816
#
# ---------29----------
# Rule: ['Pears brown bosc'] -> ['Banana Cavendish']
#     - Support: 0.004028136506017475
#     - Confidence: 0.39815317762085817
#     - Lift: 1.6760805452996406
#
# ---------30----------
# Rule: ['3kg Valencia Oranges'] -> ['Banana Cavendish']
#     - Support: 0.003967686981370556
#     - Confidence: 0.38754696725711224
#     - Lift: 1.6314322444716662
#
# ---------31----------
# Rule: ['Cucumber continental', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.0038577787547397924
#     - Confidence: 0.37580299785867244
#     - Lift: 1.5819943905508738
#
# ---------32----------
# Rule: ['Field Tomatoes', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0037368797054459528
#     - Confidence: 0.47752808988764045
#     - Lift: 2.010220152146897
#
# ---------33----------
# Rule: ['Field Tomatoes', 'Beans green'] -> ['Banana Cavendish']
#     - Support: 0.0037313842941144146
#     - Confidence: 0.46284935241990455
#     - Lift: 1.9484279885222204
#
# ---------34----------
# Rule: ['Beans green', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.003709402648788262
#     - Confidence: 0.44291338582677164
#     - Lift: 1.8645047960510244
#
# ---------35----------
# Rule: ['Broccoli', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.003709402648788262
#     - Confidence: 0.41666666666666663
#     - Lift: 1.7540156229517043
#
# ---------36----------
# Rule: ['Capsicum red', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.0036709347694674948
#     - Confidence: 0.4450366422385077
#     - Lift: 1.8734429358535463
#
# ---------37----------
# Rule: ['Potato sweet Gold', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.003610485244820575
#     - Confidence: 0.492503748125937
#     - Lift: 2.073262244580395
#
# ---------38----------
# Rule: ['Carrots ', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0035939990108259604
#     - Confidence: 0.49099099099099097
#     - Lift: 2.0668940854241704
#
# ---------39----------
# Rule: ['Field Tomatoes', 'Carrots 1kg'] -> ['Banana Cavendish']
#     - Support: 0.0035885035994944223
#     - Confidence: 0.4819188191881919
#     - Lift: 2.028703530841263
#
# ---------40----------
# Rule: ['Pear Packham', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.003451118316205968
#     - Confidence: 0.6236345580933466
#     - Lift: 2.625275418979949
#
# ---------41----------
# Rule: ['Field Tomatoes', 'Carrots '] -> ['Banana Cavendish']
#     - Support: 0.00344562290487443
#     - Confidence: 0.4879377431906615
#     - Lift: 2.0540410190021205
#
# ---------42----------
# Rule: ['Field Tomatoes', 'Lettuce Iceberg'] -> ['Banana Cavendish']
#     - Support: 0.0034401274935428917
#     - Confidence: 0.36932153392330386
#     - Lift: 1.554709776945511
#
# ---------43----------
# Rule: ['Pear Packham', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.003418145848216739
#     - Confidence: 0.6359918200408998
#     - Lift: 2.6772950122109456
#
# ---------44----------
# Rule: ['Pear Packham', 'Apples Pink Lady'] -> ['Banana Cavendish']
#     - Support: 0.0032972467989228994
#     - Confidence: 0.6122448979591837
#     - Lift: 2.577329078622913
#
# ---------45----------
# Rule: ['Field Tomatoes', 'Pumpkin Japanese/Kent'] -> ['Banana Cavendish']
#     - Support: 0.0032422926856075177
#     - Confidence: 0.45349730976172176
#     - Lift: 1.9090592790927083
#
# ---------46----------
# Rule: ['Carrots 1kg', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0032313018629444414
#     - Confidence: 0.4626278520849725
#     - Lift: 1.947495552407117
#
# ---------47----------
# Rule: ['Orange valencia'] -> ['Banana Cavendish']
#     - Support: 0.0032038248062867506
#     - Confidence: 0.37516087516087515
#     - Lift: 1.5792912867657818
#
# ---------48----------
# Rule: ['Capsicum red', 'Potato sweet Gold'] -> ['Banana Cavendish']
#     - Support: 0.0032038248062867506
#     - Confidence: 0.46827309236947795
#     - Lift: 1.9712599675775302
#
# ---------49----------
# Rule: ['Banana Cavendish', 'Capsicum green'] -> ['Capsicum red']
#     - Support: 0.003187338572292136
#     - Confidence: 0.3687221869040051
#     - Lift: 5.878427926311705
#
# ---------50----------
# Rule: ['Mushroom Cup', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0031653569269659834
#     - Confidence: 0.4357034795763994
#     - Lift: 1.8341537043634162
#
# ---------51----------
# Rule: ['Field Tomatoes', 'Mushroom Cup'] -> ['Banana Cavendish']
#     - Support: 0.003148870692971369
#     - Confidence: 0.4431554524361949
#     - Lift: 1.8655238087263606
#
# ---------52----------
# Rule: ['Apples Golden Delicious'] -> ['Banana Cavendish']
#     - Support: 0.0030719349343298345
#     - Confidence: 0.3970170454545454
#     - Lift: 1.6712978407329593
#
# ---------53----------
# Rule: ['Capsicum red', 'Mushroom Cup'] -> ['Banana Cavendish']
#     - Support: 0.003016980821014453
#     - Confidence: 0.41402714932126694
#     - Lift: 1.742904211765585
#
# ---------54----------
# Rule: ['Potato sweet Gold', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.002923558828378304
#     - Confidence: 0.4493243243243243
#     - Lift: 1.891492523129
#
# ---------55----------
# Rule: ['Banana Cavendish', 'Capsicum green'] -> ['Field Tomatoes']
#     - Support: 0.0029070725943836895
#     - Confidence: 0.33630006357279085
#     - Lift: 3.015052597346443
#
# ---------56----------
# Rule: ['Apples Pink Lady', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.002852118481068308
#     - Confidence: 0.6163895486935866
#     - Lift: 2.594776555758483
#
# ---------57----------
# Rule: ['Mandarin Imperial', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0028466230697367697
#     - Confidence: 0.6079812206572769
#     - Lift: 2.559380542785867
#
# ---------58----------
# Rule: ['Capsicum red', 'Broccoli'] -> ['Field Tomatoes']
#     - Support: 0.002791668956421388
#     - Confidence: 0.3090024330900243
#     - Lift: 2.770319394461828
#
# ---------59----------
# Rule: ['Carrots ', 'Beans green'] -> ['Banana Cavendish']
#     - Support: 0.0027806781337583117
#     - Confidence: 0.4676524953789279
#     - Lift: 1.9686474792167743
#
# ---------60----------
# Rule: ['Field Tomatoes', 'Orange navel'] -> ['Banana Cavendish']
#     - Support: 0.002720228609111392
#     - Confidence: 0.5305466237942121
#     - Lift: 2.2334089604143887
#
# ---------61----------
# Rule: ['Pink lady kids pack 1kg'] -> ['Banana Cavendish']
#     - Support: 0.0027147331977798537
#     - Confidence: 0.3742424242424242
#     - Lift: 1.5754249413420762
#
# ---------62----------
# Rule: ['Broccoli', 'Zucchini green'] -> ['Capsicum red']
#     - Support: 0.002692751552453701
#     - Confidence: 0.3024691358024691
#     - Lift: 4.822175279654398
#
# ---------63----------
# Rule: ['Carrots ', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.002687256141122163
#     - Confidence: 0.4377797672336615
#     - Lift: 1.8428941227360072
#
# ---------64----------
# Rule: ['Field Tomatoes', 'Zucchini green'] -> ['Capsicum red']
#     - Support: 0.002687256141122163
#     - Confidence: 0.30018416206261506
#     - Lift: 4.785746624367799
#
# ---------65----------
# Rule: ['Capsicum red', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.0026817607297906247
#     - Confidence: 0.556442417331813
#     - Lift: 2.3424208638552293
#
# ---------66----------
# Rule: ['Capsicum red', 'Apples Pink Lady'] -> ['Banana Cavendish']
#     - Support: 0.0026762653184590865
#     - Confidence: 0.5484234234234234
#     - Lift: 2.308663806425622
#
# ---------67----------
# Rule: ['Capsicum red', 'Carrots 1kg'] -> ['Banana Cavendish']
#     - Support: 0.0026707699071275483
#     - Confidence: 0.4677574590952839
#     - Lift: 1.96908933841277
#
# ---------68----------
# Rule: ['Apples Pink Lady', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.00266527449579601
#     - Confidence: 0.5753262158956108
#     - Lift: 2.421914810339008
#
# ---------69----------
# Rule: ['Cucumber Lebanese', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.002659779084464472
#     - Confidence: 0.4898785425101215
#     - Lift: 2.062211080587753
#
# ---------70----------
# Rule: ['Pear Packham', 'Capsicum red'] -> ['Banana Cavendish']
#     - Support: 0.002659779084464472
#     - Confidence: 0.5953259532595325
#     - Lift: 2.506106454638007
#
# ---------71----------
# Rule: ['Pear Packham', 'Potato sweet Gold'] -> ['Banana Cavendish']
#     - Support: 0.002659779084464472
#     - Confidence: 0.6213093709884467
#     - Lift: 2.615487224160077
#
# ---------72----------
# Rule: ['Onion brown', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.002654283673132934
#     - Confidence: 0.36425339366515835
#     - Lift: 1.5333747436844765
#
# ---------73----------
# Rule: ['Kensington Pride Mango'] -> ['Banana Cavendish']
#     - Support: 0.0026432928504698575
#     - Confidence: 0.41076003415883855
#     - Lift: 1.7291508412770686
#
# ---------74----------
# Rule: ['Berries Strawberry (medium)', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.0026158157938121667
#     - Confidence: 0.6279683377308707
#     - Lift: 2.643519060237503
#
# ---------75----------
# Rule: ['Banana Cavendish', 'Ginger'] -> ['Field Tomatoes']
#     - Support: 0.0026158157938121667
#     - Confidence: 0.3115183246073298
#     - Lift: 2.7928752785532738
#
# ---------76----------
# Rule: ['Avocado Shepard'] -> ['Banana Cavendish']
#     - Support: 0.002593834148486014
#     - Confidence: 0.439888164026095
#     - Lift: 1.8517697089279501
#
# ---------77----------
# Rule: ['Mint fresh'] -> ['Coriander']
#     - Support: 0.002588338737154476
#     - Confidence: 0.4095652173913043
#     - Lift: 12.65126168879573
#
# ---------78----------
# Rule: ['Capsicum red', 'Carrots '] -> ['Banana Cavendish']
#     - Support: 0.002588338737154476
#     - Confidence: 0.46679881070366697
#     - Lift: 1.9650537761988174
#
# ---------79----------
# Rule: ['Field Tomatoes', 'Apples Royal Gala'] -> ['Banana Cavendish']
#     - Support: 0.0025498708578337087
#     - Confidence: 0.5523809523809523
#     - Lift: 2.3253235687131166
#
# ---------80----------
# Rule: ['Mushroom Cup', 'Broccoli'] -> ['Capsicum red']
#     - Support: 0.0025498708578337087
#     - Confidence: 0.35098335854765506
#     - Lift: 5.59562307297326
#
# ---------81----------
# Rule: ['Field Tomatoes', 'Potato brushed'] -> ['Banana Cavendish']
#     - Support: 0.002500412155849865
#     - Confidence: 0.4033687943262411
#     - Lift: 1.6980364009426074
#
# ---------82----------
# Rule: ['Cauliflower', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.0024729350991921743
#     - Confidence: 0.47770700636942676
#     - Lift: 2.0109733256771136
#
# ---------83----------
# Rule: ['Field Tomatoes', 'Beans green'] -> ['Broccoli']
#     - Support: 0.00245644886519756
#     - Confidence: 0.30470347648261753
#     - Lift: 5.649774976109834
#
# ---------84----------
# Rule: ['Capsicum red', 'Onion spring'] -> ['Banana Cavendish']
#     - Support: 0.0024454580425344835
#     - Confidence: 0.3571428571428571
#     - Lift: 1.5034419625300321
#
# ---------85----------
# Rule: ['Capsicum red', 'Beans green'] -> ['Banana Cavendish']
#     - Support: 0.0024399626312029453
#     - Confidence: 0.43023255813953487
#     - Lift: 1.811123108350132
#
# ---------86----------
# Rule: ['Cauliflower', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0024399626312029453
#     - Confidence: 0.398921832884097
#     - Lift: 1.6793163053165643
#
# ---------87----------
# Rule: ['Onion brown', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.0024234763972083313
#     - Confidence: 0.4656810982048575
#     - Lift: 1.9603486117551048
#
# ---------88----------
# Rule: [' Australian Asparagus green'] -> ['Banana Cavendish']
#     - Support: 0.002412485574545255
#     - Confidence: 0.36013125512715344
#     - Lift: 1.5160220347349598
#
# ---------89----------
# Rule: ['Cucumber Lebanese', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.0024069901632137168
#     - Confidence: 0.44467005076142135
#     - Lift: 1.8718997186262254
#
# ---------90----------
# Rule: ['Mushroom Cup', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.0024069901632137168
#     - Confidence: 0.3903743315508022
#     - Lift: 1.6433344232146454
#
# ---------91----------
# Rule: ['Potato washed', 'Field Tomatoes'] -> ['Banana Cavendish']
#     - Support: 0.0024014947518821786
#     - Confidence: 0.39440433212996395
#     - Lift: 1.6602992647578954
#
# ---------92----------
# Rule: ['Capsicum red', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0023959993405506404
#     - Confidence: 0.5011494252873563
#     - Lift: 2.1096574113294984
#
# ---------93----------
# Rule: ['Sundowner Apples'] -> ['Banana Cavendish']
#     - Support: 0.002385008517887564
#     - Confidence: 0.4225900681596884
#     - Lift: 1.778950995975166
#
# ---------94----------
# Rule: ['Beans green', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.002385008517887564
#     - Confidence: 0.4082784571966134
#     - Lift: 1.7187043018499488
#
# ---------95----------
# Rule: ['Pumpkin Japanese/Kent', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.002346540638566797
#     - Confidence: 0.45137420718816074
#     - Lift: 1.9001217868931364
#
# ---------96----------
# Rule: ['Broccoli', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0022970819365829534
#     - Confidence: 0.5749656121045392
#     - Lift: 2.4203967990992434
#
# ---------97----------
# Rule: ['Capsicum red', 'Onion brown'] -> ['Banana Cavendish']
#     - Support: 0.0022970819365829534
#     - Confidence: 0.39923591212989495
#     - Lift: 1.6806384650861033
#
# ---------98----------
# Rule: ['Cucumber Lebanese', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.002280595702588339
#     - Confidence: 0.5382619974059664
#     - Lift: 2.2658878864590117
#
# ---------99----------
# Rule: ['Capsicum red', 'Cucumber continental'] -> ['Banana Cavendish']
#     - Support: 0.0022641094685937244
#     - Confidence: 0.4003887269193392
#     - Lift: 1.6854913974486352
#
# ---------100----------
# Rule: ['Capsicum red', 'Mushroom Cup'] -> ['Zucchini green']
#     - Support: 0.0022586140572621862
#     - Confidence: 0.30995475113122173
#     - Lift: 6.569120203045472
#
# ---------101----------
# Rule: ['Cocktail Potatoes'] -> ['Banana Cavendish']
#     - Support: 0.002253118645930648
#     - Confidence: 0.36315323294951285
#     - Lift: 1.5287434658852765
#
# ---------102----------
# Rule: ['Carrots 1kg', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.002253118645930648
#     - Confidence: 0.4311251314405889
#     - Lift: 1.81488051838536
#
# ---------103----------
# Rule: ['Pear Packham', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.002253118645930648
#     - Confidence: 0.5959302325581396
#     - Lift: 2.5086502514309266
#
# ---------104----------
# Rule: ['Potato sweet Gold', 'Carrots 1kg'] -> ['Banana Cavendish']
#     - Support: 0.00224762323459911
#     - Confidence: 0.47447795823665895
#     - Lift: 1.9973802035839827
#
# ---------105----------
# Rule: ['Capsicum green', 'Field Tomatoes'] -> ['Capsicum red']
#     - Support: 0.00224762323459911
#     - Confidence: 0.32003129890453835
#     - Lift: 5.102163611499811
#
# ---------106----------
# Rule: ['Potato sweet Gold', 'Pumpkin Japanese/Kent'] -> ['Banana Cavendish']
#     - Support: 0.0022366324119360336
#     - Confidence: 0.3775510204081633
#     - Lift: 1.589352931817463
#
# ---------107----------
# Rule: ['Mushroom Cup', 'Broccoli'] -> ['Field Tomatoes']
#     - Support: 0.0022366324119360336
#     - Confidence: 0.30786686838124055
#     - Lift: 2.760138643116438
#
# ---------108----------
# Rule: ['kiwifruit multibuy 5 for $2'] -> ['Banana Cavendish']
#     - Support: 0.002220146177941419
#     - Confidence: 0.4035964035964036
#     - Lift: 1.6989945534605122
#
# ---------109----------
# Rule: ['Capsicum yellow'] -> ['Capsicum red']
#     - Support: 0.002220146177941419
#     - Confidence: 0.4622425629290618
#     - Lift: 7.369395407061623
#
# ---------110----------
# Rule: ['Banana Cavendish', 'Coriander'] -> ['Field Tomatoes']
#     - Support: 0.0022036599439468046
#     - Confidence: 0.3270799347471452
#     - Lift: 2.9323907831668725
#
# ---------111----------
# Rule: ['Pandan Leaves'] -> ['Curry Leaves']
#     - Support: 0.0021981645326152664
#     - Confidence: 0.6359300476947536
#     - Lift: 71.47633772638315
#
# ---------112----------
# Rule: ['Lettuce Iceberg', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.00218717370995219
#     - Confidence: 0.3664825046040516
#     - Lift: 1.5427584926735434
#
# ---------113----------
# Rule: ['Pear Packham', 'Carrots '] -> ['Banana Cavendish']
#     - Support: 0.0021761828872891137
#     - Confidence: 0.6275752773375595
#     - Lift: 2.6418644184679874
#
# ---------114----------
# Rule: ['Potato sweet Gold', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.0021706874759575756
#     - Confidence: 0.47647768395657425
#     - Lift: 2.0057983239544224
#
# ---------115----------
# Rule: ['Kensington Pride Mangoes large'] -> ['Banana Cavendish']
#     - Support: 0.0021651920646260374
#     - Confidence: 0.3983822042467139
#     - Lift: 1.6770446643712154
#
# ---------116----------
# Rule: ['Cucumber Lebanese', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0021651920646260374
#     - Confidence: 0.4028629856850716
#     - Lift: 1.6959071299214028
#
# ---------117----------
# Rule: ['Capsicum red', 'Lettuce Iceberg'] -> ['Banana Cavendish']
#     - Support: 0.0021596966532944992
#     - Confidence: 0.40473738414006183
#     - Lift: 1.7037976679382574
#
# ---------118----------
# Rule: ['Potato sweet Gold', 'Carrots '] -> ['Banana Cavendish']
#     - Support: 0.0021322195966368084
#     - Confidence: 0.47901234567901235
#     - Lift: 2.0164683309785523
#
# ---------119----------
# Rule: ['Potato sweet Gold', 'Onion brown'] -> ['Banana Cavendish']
#     - Support: 0.0021322195966368084
#     - Confidence: 0.4674698795180723
#     - Lift: 1.9678787326417195
#
# ---------120----------
# Rule: ['Carrots ', 'Beans green'] -> ['Broccoli']
#     - Support: 0.0021322195966368084
#     - Confidence: 0.35859519408502777
#     - Lift: 6.649028680217292
#
# ---------121----------
# Rule: ['Capsicum red', 'Garlic loose'] -> ['Banana Cavendish']
#     - Support: 0.0021267241853052702
#     - Confidence: 0.36717267552182165
#     - Lift: 1.545663862047005
#
# ---------122----------
# Rule: ['Cucumber continental', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0021047425399791176
#     - Confidence: 0.42087912087912094
#     - Lift: 1.771748528150777
#
# ---------123----------
# Rule: ['Field Tomatoes', 'Apples Granny Smith'] -> ['Banana Cavendish']
#     - Support: 0.0020937517173160412
#     - Confidence: 0.5026385224274407
#     - Lift: 2.11592597048422
#
# ---------124----------
# Rule: ['Capsicum red', 'Eggplant'] -> ['Zucchini green']
#     - Support: 0.0020937517173160412
#     - Confidence: 0.31435643564356436
#     - Lift: 6.662408641283416
#
# ---------125----------
# Rule: ['Berries Strawberry (medium)', 'Broccoli'] -> ['Banana Cavendish']
#     - Support: 0.002082760894652965
#     - Confidence: 0.684115523465704
#     - Lift: 2.879878358550308
#
# ---------126----------
# Rule: ['Carrots 1kg', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.002082760894652965
#     - Confidence: 0.5
#     - Lift: 2.1048187475420455
#
# ---------127----------
# Rule: ['Capsicum red', 'Beans green'] -> ['Broccoli']
#     - Support: 0.0020772654833214267
#     - Confidence: 0.3662790697674419
#     - Lift: 6.791502172975484
#
# ---------128----------
# Rule: ['Cucumber continental', 'Lettuce Iceberg'] -> ['Field Tomatoes']
#     - Support: 0.0020772654833214267
#     - Confidence: 0.314214463840399
#     - Lift: 2.817047149087915
#
# ---------129----------
# Rule: ['Berries Strawberry (medium)', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0020717700719898886
#     - Confidence: 0.5207182320441989
#     - Lift: 2.1920349939871575
#
# ---------130----------
# Rule: ['Pear Packham', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.0020717700719898886
#     - Confidence: 0.556047197640118
#     - Lift: 2.340757132222275
#
# ---------131----------
# Rule: ['Field Tomatoes', 'Lemon'] -> ['Banana Cavendish']
#     - Support: 0.0020717700719898886
#     - Confidence: 0.3736372646184341
#     - Lift: 1.5728774386984166
#
# ---------132----------
# Rule: ['Potato sweet Gold', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.0020717700719898886
#     - Confidence: 0.5576923076923077
#     - Lift: 2.3476824491815123
#
# ---------133----------
# Rule: ['Pear Packham', 'Orange navel'] -> ['Banana Cavendish']
#     - Support: 0.0020662746606583504
#     - Confidence: 0.5911949685534591
#     - Lift: 2.4887165065277013
#
# ---------134----------
# Rule: ['Afourer Mandarin'] -> ['Banana Cavendish']
#     - Support: 0.0020607792493268122
#     - Confidence: 0.37575150300601207
#     - Lift: 1.5817776158883108
#
# ---------135----------
# Rule: ['Pear Packham', 'Apples Royal Gala'] -> ['Banana Cavendish']
#     - Support: 0.002049788426663736
#     - Confidence: 0.5720858895705522
#     - Lift: 2.408274211144733
#
# ---------136----------
# Rule: ['Pears William'] -> ['Banana Cavendish']
#     - Support: 0.0020442930153321977
#     - Confidence: 0.3625730994152047
#     - Lift: 1.5263013140070973
#
# ---------137----------
# Rule: ['Potato sweet Gold', 'Beans green'] -> ['Banana Cavendish']
#     - Support: 0.0020278067813375832
#     - Confidence: 0.4913448735019974
#     - Lift: 2.0683838025113577
#
# ---------138----------
# Rule: ['Nectarine White', 'Watermelon seedless'] -> ['Banana Cavendish']
#     - Support: 0.0020278067813375832
#     - Confidence: 0.4160090191657272
#     - Lift: 1.7512471653732014
#
# ---------139----------
# Rule: ['Carrots ', 'Cucumber Lebanese'] -> ['Banana Cavendish']
#     - Support: 0.002016815958674507
#     - Confidence: 0.4729381443298969
#     - Lift: 1.9908981452266254
#
# ---------140----------
# Rule: ['Carrots 1kg', 'Beans green'] -> ['Banana Cavendish']
#     - Support: 0.0020058251360114306
#     - Confidence: 0.4259043173862311
#     - Lift: 1.7929027837872733
#
# ---------141----------
# Rule: ['Capsicum red', 'Pumpkin Japanese/Kent'] -> ['Banana Cavendish']
#     - Support: 0.0020058251360114306
#     - Confidence: 0.4366028708133971
#     - Lift: 1.8379398154374318
#
# ---------142----------
# Rule: ['Apples Pink Lady', 'Zucchini green'] -> ['Banana Cavendish']
#     - Support: 0.0020003297246798924
#     - Confidence: 0.5498489425981873
#     - Lift: 2.314664725393669
#
# ---------143----------
# Rule: ['Apples Royal Gala', 'Mandarin Imperial'] -> ['Banana Cavendish']
#     - Support: 0.0020003297246798924
#     - Confidence: 0.558282208588957
#     - Lift: 2.350165718114431

# %%
print(one2one_rules)
print(supports)
# Out:
# [('Mandarin Imperial', 'Banana Cavendish'), ('Apples Pink Lady', 'Banana Cavendish'), ('Pear Packham', 'Banana Cavendish'), ('Apples Royal Gala', 'Banana Cavendish'), ('Orange navel', 'Banana Cavendish'), ('Nectarine White', 'Banana Cavendish'), ('Berries Strawberry (medium)', 'Banana Cavendish'), ('Capsicum green', 'Capsicum red'), ('Apples Granny Smith', 'Banana Cavendish'), ('Nectarine Yellow', 'Banana Cavendish'), ('Kiwi fruit Green', 'Banana Cavendish'), ('Avocado Hass Medium', 'Banana Cavendish'), ('navel oranges 3kg', 'Banana Cavendish'), ('Tomatoes Cherry', 'Banana Cavendish'), ('Cauliflower half', 'Broccoli'), ('Berries Strawberry (large)', 'Banana Cavendish'), ('Brussels sprouts', 'Banana Cavendish'), ('Apples Red Delicious', 'Banana Cavendish'), ('Pears brown bosc', 'Banana Cavendish'), ('3kg Valencia Oranges', 'Banana Cavendish'), ('Orange valencia', 'Banana Cavendish'), ('Apples Golden Delicious', 'Banana Cavendish'), ('Pink lady kids pack 1kg', 'Banana Cavendish'), ('Kensington Pride Mango', 'Banana Cavendish'), ('Avocado Shepard', 'Banana Cavendish'), ('Mint fresh', 'Coriander'), (' Australian Asparagus green', 'Banana Cavendish'), ('Sundowner Apples', 'Banana Cavendish'), ('Cocktail Potatoes', 'Banana Cavendish'), ('kiwifruit multibuy 5 for $2', 'Banana Cavendish'), ('Capsicum yellow', 'Capsicum red'), ('Pandan Leaves', 'Curry Leaves'), ('Kensington Pride Mangoes large', 'Banana Cavendish'), ('Afourer Mandarin', 'Banana Cavendish'), ('Pears William', 'Banana Cavendish')]
# [0.0225916359839534, 0.01992086607682585, 0.018926196625817442, 0.012513051601912403, 0.012375666318623949, 0.011260097818321702, 0.010314887069297137, 0.010062098148046381, 0.010012639446062538, 0.008501401329889541, 0.0066329614771665655, 0.006545034895861955, 0.005215145353629719, 0.0045831730505028305, 0.0043029070725943835, 0.0041545309666428535, 0.0041050722646590095, 0.004061108974006704, 0.004028136506017475, 0.003967686981370556, 0.0032038248062867506, 0.0030719349343298345, 0.0027147331977798537, 0.0026432928504698575, 0.002593834148486014, 0.002588338737154476, 0.002412485574545255, 0.002385008517887564, 0.002253118645930648, 0.002220146177941419, 0.002220146177941419, 0.0021981645326152664, 0.0021651920646260374, 0.0020607792493268122, 0.0020442930153321977]

# %% [markdown]
# # Visualization

# %%
lift_size= [int(i*1000) for i in lifts]
edge_width = [i * 10 for i in confidences] 
node_color=[i * 40 for i in supports]

scaler =MinMaxScaler(feature_range=(0, 13))
node_color=scaler.fit_transform((np.array(node_color)).reshape(-1,1))
node_color=(np.around(node_color.reshape(-1))).tolist()

G = nx.Graph()
plt.figure(2, figsize=(50, 50))
G.add_edges_from(one2one_rules) 
nx.draw_networkx(G, with_label = True, width=edge_width, node_size=10000,
                 edge_color ='.4', cmap=plt.cm.Blues, font_weight='bold', font_size=25) 
plt.show()
